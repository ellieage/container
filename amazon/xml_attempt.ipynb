# %%
import xml.etree.ElementTree as ET

# %%
import xml.etree.ElementTree as ET
tree1 = ET.parse('country_data.xml')
root1 = tree1.getroot()

# %%
root1
# Out:
# <Element 'data' at 0x1109b59a8>

# %%
root1.tag
# Out:
# 'data'

# %%
root1.attrib
# Out:
# {}

# %%
for child in root1:
...     print(child.tag, child.attrib)
# Out:
# country {'name': 'Liechtenstein'}
# country {'name': 'Singapore'}
# country {'name': 'Panama'}

# %%
for neighbor in root1.iter('neighbor'):
    print(neighbor.attrib)
# Out:
# {'name': 'Austria', 'direction': 'E'}
# {'name': 'Switzerland', 'direction': 'W'}
# {'name': 'Malaysia', 'direction': 'N'}
# {'name': 'Costa Rica', 'direction': 'W'}
# {'name': 'Colombia', 'direction': 'E'}

# %%
for rank in root1.iter('rank'):
    print(rank.text)
# Out:
# 1
# 4
# 68

# %%
root1.iter('neighbor')

# %%
for country in root1.findall('country'):
...     rank = country.find('rank').text
...     name = country.get('name')
...     print(name, rank)
# Out:
# Liechtenstein 1
# Singapore 4
# Panama 68

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('Response.xml')
root = tree.getroot()

# %%
root.tag
# Out:
# '{http://webservices.amazon.com/AWSECommerceService/2011-08-01}ItemSearchResponse'

# %%
root.attrib
# Out:
# {}

# %%
for item in root[1].iter('Item'):
    print(item)

# %%
root[1]

# %%
for item in root.findall('Item'):
    print(item)

# %%
for child in root:
    print(child[0:10])
# Out:
# [<Element '{http://webservices.amazon.com/AWSECommerceService/2011-08-01}HTTPHeaders' at 0x1109694f8>, <Element '{http://webservices.amazon.com/AWSECommerceService/2011-08-01}RequestId' at 0x110969688>, <Element '{http://webservices.amazon.com/AWSECommerceService/2011-08-01}Arguments' at 0x110969598>, <Element '{http://webservices.amazon.com/AWSECommerceService/2011-08-01}RequestProcessingTime' at 0x110969a98>]
# [<Element '{http://webservices.amazon.com/AWSECommerceService/2011-08-01}Request' at 0x110969b38>, <Element '{http://webservices.amazon.com/AWSECommerceService/2011-08-01}TotalResults' at 0x110969d68>, <Element '{http://webservices.amazon.com/AWSECommerceService/2011-08-01}TotalPages' at 0x110969db8>, <Element '{http://webservices.amazon.com/AWSECommerceService/2011-08-01}Item' at 0x110969e08>]

# %%
root.findall(".")
# Out:
# [<Element '{http://webservices.amazon.com/AWSECommerceService/2011-08-01}ItemSearchResponse' at 0x11093e9f8>]

# %%
tree = ET.parse('Response.xml')
root = tree.getroot()
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-10-ab55028a7373>", line 1, in <module>
#     tree = ET.parse('Response.xml')
#
#   File "/usr/local/Cellar/python/3.6.4_3/Frameworks/Python.framework/Versions/3.6/lib/python3.6/xml/etree/ElementTree.py", line 1196, in parse
#     tree.parse(source, parser)
#
#   File "/usr/local/Cellar/python/3.6.4_3/Frameworks/Python.framework/Versions/3.6/lib/python3.6/xml/etree/ElementTree.py", line 597, in parse
#     self._root = parser._parse_whole(source)
#
#   File "<string>", line unknown
# ParseError: not well-formed (invalid token): line 1, column 1

# %%
root = ET.fromstring("""/* **********Unsigned URL********** */
http://webservices.amazon.com/onca/xml?Service=AWSECommerceService&Operation=ItemSearch&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&AssociateTag=ellieage-20&SearchIndex=All&Keywords=basket&ResponseGroup=Images,ItemAttributes

/* **********Signed URL********** */
http://webservices.amazon.com/onca/xml?AWSAccessKeyId=AKIAIEPGTWIXGRZC2NVQ&AssociateTag=ellieage-20&Keywords=basket&Operation=ItemSearch&ResponseGroup=Images%2CItemAttributes&SearchIndex=All&Service=AWSECommerceService&Timestamp=2018-03-27T20%3A57%3A12.000Z&Signature=fNAVpAwx9T0VfBuROPytsXAfpSp6cSB6%2BovM5QEbWLo%3D

/* **********Response********** */
<?xml version="1.0" ?>
<ItemSearchResponse
    xmlns="http://webservices.amazon.com/AWSECommerceService/2011-08-01">
    <OperationRequest>
        <HTTPHeaders>
            <Header Name="UserAgent" Value="Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36"></Header>
        </HTTPHeaders>
        <RequestId>11eada55-d020-4692-9727-1611a5dedec8</RequestId>
        <Arguments>
            <Argument Name="AWSAccessKeyId" Value="AKIAIEPGTWIXGRZC2NVQ"></Argument>
            <Argument Name="AssociateTag" Value="ellieage-20"></Argument>
            <Argument Name="Keywords" Value="basket"></Argument>
            <Argument Name="Operation" Value="ItemSearch"></Argument>
            <Argument Name="ResponseGroup" Value="Images,ItemAttributes"></Argument>
            <Argument Name="SearchIndex" Value="All"></Argument>
            <Argument Name="Service" Value="AWSECommerceService"></Argument>
            <Argument Name="Timestamp" Value="2018-03-27T20:57:12.000Z"></Argument>
            <Argument Name="Signature" Value="fNAVpAwx9T0VfBuROPytsXAfpSp6cSB6+ovM5QEbWLo="></Argument>
        </Arguments>
        <RequestProcessingTime>0.1489244760000000</RequestProcessingTime>
    </OperationRequest>
    <Items>
        <Request>
            <IsValid>True</IsValid>
            <ItemSearchRequest>
                <Keywords>basket</Keywords>
                <ResponseGroup>Images</ResponseGroup>
                <ResponseGroup>ItemAttributes</ResponseGroup>
                <SearchIndex>All</SearchIndex>
            </ItemSearchRequest>
        </Request>
        <TotalResults>418442</TotalResults>
        <TotalPages>41845</TotalPages>
        <MoreSearchResultsUrl>https://www.amazon.com/gp/search?linkCode=xm2&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&keywords=basket&tag=ellieage-20&creative=386001&url=search-alias%3Daws-amazon-aps&camp=2025</MoreSearchResultsUrl>
        <Item>
            <ASIN>B01A9ZKRIA</ASIN>
            <ParentASIN>B07BB3G3CC</ParentASIN>
            <DetailPageURL>https://www.amazon.com/TheWarmHome-Small-Storage-Basket-Linen/dp/B01A9ZKRIA?psc=1&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=165953&creativeASIN=B01A9ZKRIA</DetailPageURL>
            <ItemLinks>
                <ItemLink>
                    <Description>Technical Details</Description>
                    <URL>https://www.amazon.com/TheWarmHome-Small-Storage-Basket-Linen/dp/tech-data/B01A9ZKRIA?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01A9ZKRIA</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Baby Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/baby/add-item.html?asin.0=B01A9ZKRIA&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01A9ZKRIA</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wedding Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/wedding/add-item.html?asin.0=B01A9ZKRIA&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01A9ZKRIA</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wishlist</Description>
                    <URL>https://www.amazon.com/gp/registry/wishlist/add-item.html?asin.0=B01A9ZKRIA&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01A9ZKRIA</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Tell A Friend</Description>
                    <URL>https://www.amazon.com/gp/pdp/taf/B01A9ZKRIA?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01A9ZKRIA</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Customer Reviews</Description>
                    <URL>https://www.amazon.com/review/product/B01A9ZKRIA?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01A9ZKRIA</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Offers</Description>
                    <URL>https://www.amazon.com/gp/offer-listing/B01A9ZKRIA?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01A9ZKRIA</URL>
                </ItemLink>
            </ItemLinks>
            <SmallImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/615DHrch67L._SL75_.jpg</URL>
                <Height Units="pixels">75</Height>
                <Width Units="pixels">75</Width>
            </SmallImage>
            <MediumImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/615DHrch67L._SL160_.jpg</URL>
                <Height Units="pixels">160</Height>
                <Width Units="pixels">160</Width>
            </MediumImage>
            <LargeImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/615DHrch67L.jpg</URL>
                <Height Units="pixels">500</Height>
                <Width Units="pixels">500</Width>
            </LargeImage>
            <ImageSets>
                <ImageSet Category="swatch">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41YRgQAabTL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41YRgQAabTL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41YRgQAabTL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41YRgQAabTL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41YRgQAabTL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41YRgQAabTL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61W%2BjmFXgaL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61W%2BjmFXgaL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61W%2BjmFXgaL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61W%2BjmFXgaL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61W%2BjmFXgaL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61W%2BjmFXgaL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61m1onA%2B2nL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61m1onA%2B2nL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61m1onA%2B2nL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61m1onA%2B2nL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61m1onA%2B2nL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61m1onA%2B2nL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51-SyhTasxL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51-SyhTasxL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51-SyhTasxL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51-SyhTasxL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51-SyhTasxL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51-SyhTasxL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61lQiT1IPdL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61lQiT1IPdL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61lQiT1IPdL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61lQiT1IPdL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61lQiT1IPdL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61lQiT1IPdL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51-NHZgsqIL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51-NHZgsqIL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51-NHZgsqIL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51-NHZgsqIL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51-NHZgsqIL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51-NHZgsqIL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61dXdkBHPtL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61dXdkBHPtL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61dXdkBHPtL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61dXdkBHPtL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61dXdkBHPtL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61dXdkBHPtL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="primary">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/615DHrch67L._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/615DHrch67L._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/615DHrch67L._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/615DHrch67L._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/615DHrch67L._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/615DHrch67L.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
            </ImageSets>
            <ItemAttributes>
                <Binding>Kitchen</Binding>
                <Brand>TheWarmHome</Brand>
                <CatalogNumberList>
                    <CatalogNumberListElement>HCM01</CatalogNumberListElement>
                </CatalogNumberList>
                <Color>Grey</Color>
                <EAN>0602668163259</EAN>
                <EANList>
                    <EANListElement>0602668163259</EANListElement>
                </EANList>
                <Feature>Natural linen material</Feature>
                <Feature>Sturdy linen construction</Feature>
                <Feature>Stylish appearance</Feature>
                <Feature>Rope handle for easy slide in and pull out of shelves or cabinet</Feature>
                <Feature>Collapsible for easy storage if not in use,11.8L×7.9W×5.1H(inch)</Feature>
                <IsAdultProduct>0</IsAdultProduct>
                <IsAutographed>0</IsAutographed>
                <ItemDimensions>
                    <Height Units="hundredths-inches">510</Height>
                    <Length Units="hundredths-inches">1180</Length>
                    <Weight Units="Pounds">0.99</Weight>
                    <Width Units="hundredths-inches">790</Width>
                </ItemDimensions>
                <Label>TheWarmHome Co.,Ltd</Label>
                <ListPrice>
                    <Amount>999</Amount>
                    <CurrencyCode>USD</CurrencyCode>
                    <FormattedPrice>$9.99</FormattedPrice>
                </ListPrice>
                <Manufacturer>TheWarmHome Co.,Ltd</Manufacturer>
                <Model>HCM01</Model>
                <MPN>HCM01</MPN>
                <PackageDimensions>
                    <Height Units="hundredths-inches">200</Height>
                    <Length Units="hundredths-inches">1200</Length>
                    <Weight Units="Hundredths Pounds">45</Weight>
                    <Width Units="hundredths-inches">870</Width>
                </PackageDimensions>
                <PackageQuantity>1</PackageQuantity>
                <PartNumber>HCM01</PartNumber>
                <ProductGroup>Home</ProductGroup>
                <ProductTypeName>HOME</ProductTypeName>
                <Publisher>TheWarmHome Co.,Ltd</Publisher>
                <Size>11.8*7.9*5.2inch</Size>
                <Studio>TheWarmHome Co.,Ltd</Studio>
                <Title>TheWarmHome Small Storage Basket Linen Storage Bins for Toy Storage,Grey</Title>
                <UPC>602668163259</UPC>
                <UPCList>
                    <UPCListElement>602668163259</UPCListElement>
                </UPCList>
            </ItemAttributes>
        </Item>
        <Item>
            <ASIN>B003VV2DQY</ASIN>
            <ParentASIN>B07B8K8RD4</ParentASIN>
            <DetailPageURL>https://www.amazon.com/Whitmor-Rattique-Storage-Baskets-Java/dp/B003VV2DQY?psc=1&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=165953&creativeASIN=B003VV2DQY</DetailPageURL>
            <ItemLinks>
                <ItemLink>
                    <Description>Technical Details</Description>
                    <URL>https://www.amazon.com/Whitmor-Rattique-Storage-Baskets-Java/dp/tech-data/B003VV2DQY?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B003VV2DQY</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Baby Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/baby/add-item.html?asin.0=B003VV2DQY&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B003VV2DQY</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wedding Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/wedding/add-item.html?asin.0=B003VV2DQY&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B003VV2DQY</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wishlist</Description>
                    <URL>https://www.amazon.com/gp/registry/wishlist/add-item.html?asin.0=B003VV2DQY&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B003VV2DQY</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Tell A Friend</Description>
                    <URL>https://www.amazon.com/gp/pdp/taf/B003VV2DQY?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B003VV2DQY</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Customer Reviews</Description>
                    <URL>https://www.amazon.com/review/product/B003VV2DQY?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B003VV2DQY</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Offers</Description>
                    <URL>https://www.amazon.com/gp/offer-listing/B003VV2DQY?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B003VV2DQY</URL>
                </ItemLink>
            </ItemLinks>
            <SmallImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/51F9ylbW1PL._SL75_.jpg</URL>
                <Height Units="pixels">72</Height>
                <Width Units="pixels">75</Width>
            </SmallImage>
            <MediumImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/51F9ylbW1PL._SL160_.jpg</URL>
                <Height Units="pixels">155</Height>
                <Width Units="pixels">160</Width>
            </MediumImage>
            <LargeImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/51F9ylbW1PL.jpg</URL>
                <Height Units="pixels">483</Height>
                <Width Units="pixels">500</Width>
            </LargeImage>
            <ImageSets>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51gV0NyqcjL._SL30_.jpg</URL>
                        <Height Units="pixels">17</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51gV0NyqcjL._SL75_.jpg</URL>
                        <Height Units="pixels">42</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51gV0NyqcjL._SL75_.jpg</URL>
                        <Height Units="pixels">42</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51gV0NyqcjL._SL110_.jpg</URL>
                        <Height Units="pixels">61</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51gV0NyqcjL._SL160_.jpg</URL>
                        <Height Units="pixels">89</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51gV0NyqcjL.jpg</URL>
                        <Height Units="pixels">277</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61E4yFuwMdL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61E4yFuwMdL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61E4yFuwMdL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61E4yFuwMdL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61E4yFuwMdL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61E4yFuwMdL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51rde3k181L._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">24</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51rde3k181L._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">59</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51rde3k181L._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">59</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51rde3k181L._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">87</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51rde3k181L._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">127</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51rde3k181L.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">396</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51zYMvxF2CL._SL30_.jpg</URL>
                        <Height Units="pixels">25</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51zYMvxF2CL._SL75_.jpg</URL>
                        <Height Units="pixels">63</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51zYMvxF2CL._SL75_.jpg</URL>
                        <Height Units="pixels">63</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51zYMvxF2CL._SL110_.jpg</URL>
                        <Height Units="pixels">92</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51zYMvxF2CL._SL160_.jpg</URL>
                        <Height Units="pixels">134</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51zYMvxF2CL.jpg</URL>
                        <Height Units="pixels">419</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51GSXdWzoKL._SL30_.jpg</URL>
                        <Height Units="pixels">22</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51GSXdWzoKL._SL75_.jpg</URL>
                        <Height Units="pixels">56</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51GSXdWzoKL._SL75_.jpg</URL>
                        <Height Units="pixels">56</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51GSXdWzoKL._SL110_.jpg</URL>
                        <Height Units="pixels">82</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51GSXdWzoKL._SL160_.jpg</URL>
                        <Height Units="pixels">120</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51GSXdWzoKL.jpg</URL>
                        <Height Units="pixels">375</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/31ABUwATajL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">22</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/31ABUwATajL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">56</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/31ABUwATajL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">56</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/31ABUwATajL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">82</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/31ABUwATajL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">120</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/31ABUwATajL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">375</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="primary">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51F9ylbW1PL._SL30_.jpg</URL>
                        <Height Units="pixels">29</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51F9ylbW1PL._SL75_.jpg</URL>
                        <Height Units="pixels">72</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51F9ylbW1PL._SL75_.jpg</URL>
                        <Height Units="pixels">72</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51F9ylbW1PL._SL110_.jpg</URL>
                        <Height Units="pixels">106</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51F9ylbW1PL._SL160_.jpg</URL>
                        <Height Units="pixels">155</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51F9ylbW1PL.jpg</URL>
                        <Height Units="pixels">483</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
            </ImageSets>
            <ItemAttributes>
                <Binding>Kitchen</Binding>
                <Brand>Whitmor</Brand>
                <CatalogNumberList>
                    <CatalogNumberListElement>W31571</CatalogNumberListElement>
                </CatalogNumberList>
                <Color>Java</Color>
                <EAN>6280594359706</EAN>
                <EANList>
                    <EANListElement>6280594359706</EANListElement>
                    <EANListElement>0635409949034</EANListElement>
                    <EANListElement>6092295029402</EANListElement>
                    <EANListElement>0723979099416</EANListElement>
                    <EANListElement>7892346144646</EANListElement>
                    <EANListElement>0885212516125</EANListElement>
                    <EANListElement>0885266634578</EANListElement>
                    <EANListElement>0804067204032</EANListElement>
                    <EANListElement>0885710750724</EANListElement>
                    <EANListElement>0038861056584</EANListElement>
                    <EANListElement>0885698025548</EANListElement>
                    <EANListElement>0846830073209</EANListElement>
                    <EANListElement>0743724203905</EANListElement>
                    <EANListElement>0898029689463</EANListElement>
                    <EANListElement>0885697408793</EANListElement>
                    <EANListElement>0885895654688</EANListElement>
                    <EANListElement>0809394443772</EANListElement>
                    <EANListElement>0278788831783</EANListElement>
                    <EANListElement>0885203603292</EANListElement>
                    <EANListElement>0038861095163</EANListElement>
                    <EANListElement>0863190165252</EANListElement>
                    <EANListElement>4162272653134</EANListElement>
                    <EANListElement>7426648064090</EANListElement>
                    <EANListElement>0719918462649</EANListElement>
                    <EANListElement>0882681343610</EANListElement>
                </EANList>
                <Feature>1 Small: 8.3 x 11.4 x 5.5 in.; 1 Medium 9.8 x 13 x 6 in.; 1 Large 11.4 x 14.6 x 6.5 in. (LxWxH)</Feature>
                <Feature>Solid construction of rattan-look with the durability of resin</Feature>
                <Feature>Storage containers with built-in stainless steel handles for easy transport</Feature>
                <Feature>Whitmor's versatile storage solution to organize any space in your home or office</Feature>
                <Feature>Use for clothing, bath & beauty products, toys, school supplies & more. Tuck baskets away in closets, storage cubes or on a shelf for extra storage</Feature>
                <Feature>These storage bins are easy to clean with a damp cloth</Feature>
                <Feature>Mix & Match for Stylish Storage: Whitmor storage containers come in a variety of colors and sizes</Feature>
                <Feature>Service & Guarantee. Whitmor stands by our products. If you have any problems, contact us for help.</Feature>
                <IsAdultProduct>0</IsAdultProduct>
                <IsAutographed>0</IsAutographed>
                <ItemDimensions>
                    <Height Units="hundredths-inches">650</Height>
                    <Length Units="hundredths-inches">1140</Length>
                    <Weight Units="Hundredths Pounds">265</Weight>
                    <Width Units="hundredths-inches">1460</Width>
                </ItemDimensions>
                <Label>Whitmor</Label>
                <Languages>
                    <Language>
                        <Name>English</Name>
                        <Type>Unknown</Type>
                    </Language>
                </Languages>
                <ListPrice>
                    <Amount>2099</Amount>
                    <CurrencyCode>USD</CurrencyCode>
                    <FormattedPrice>$20.99</FormattedPrice>
                </ListPrice>
                <Manufacturer>Whitmor</Manufacturer>
                <Model>6500-1959-JAVA</Model>
                <MPN>6500-1959-JAVA</MPN>
                <NumberOfItems>1</NumberOfItems>
                <PackageDimensions>
                    <Height Units="hundredths-inches">700</Height>
                    <Length Units="hundredths-inches">1700</Length>
                    <Weight Units="Hundredths Pounds">500</Weight>
                    <Width Units="hundredths-inches">1200</Width>
                </PackageDimensions>
                <PackageQuantity>1</PackageQuantity>
                <PartNumber>6500-1959-JAVA</PartNumber>
                <ProductGroup>Home</ProductGroup>
                <ProductTypeName>HOME</ProductTypeName>
                <Publisher>Whitmor</Publisher>
                <Studio>Whitmor</Studio>
                <Title>Whitmor Rattique Storage Baskets Set of 3 Java</Title>
                <UPC>885697408793</UPC>
                <UPCList>
                    <UPCListElement>885697408793</UPCListElement>
                    <UPCListElement>809394443772</UPCListElement>
                    <UPCListElement>885710750724</UPCListElement>
                    <UPCListElement>723979099416</UPCListElement>
                    <UPCListElement>885203603292</UPCListElement>
                    <UPCListElement>885698025548</UPCListElement>
                    <UPCListElement>885266634578</UPCListElement>
                    <UPCListElement>846830073209</UPCListElement>
                    <UPCListElement>885212516125</UPCListElement>
                    <UPCListElement>278788831783</UPCListElement>
                    <UPCListElement>719918462649</UPCListElement>
                    <UPCListElement>863190165252</UPCListElement>
                    <UPCListElement>804067204032</UPCListElement>
                    <UPCListElement>635409949034</UPCListElement>
                    <UPCListElement>882681343610</UPCListElement>
                    <UPCListElement>885895654688</UPCListElement>
                    <UPCListElement>743724203905</UPCListElement>
                    <UPCListElement>038861056584</UPCListElement>
                    <UPCListElement>898029689463</UPCListElement>
                    <UPCListElement>038861095163</UPCListElement>
                </UPCList>
                <Warranty>For replacement parts or assembly help call 1-888-whitmor.</Warranty>
            </ItemAttributes>
        </Item>
        <Item>
            <ASIN>B07145D93P</ASIN>
            <DetailPageURL>https://www.amazon.com/Storage-Baskets-Terracotta-Decorative-Laundry/dp/B07145D93P?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=165953&creativeASIN=B07145D93P</DetailPageURL>
            <ItemLinks>
                <ItemLink>
                    <Description>Technical Details</Description>
                    <URL>https://www.amazon.com/Storage-Baskets-Terracotta-Decorative-Laundry/dp/tech-data/B07145D93P?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B07145D93P</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Baby Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/baby/add-item.html?asin.0=B07145D93P&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B07145D93P</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wedding Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/wedding/add-item.html?asin.0=B07145D93P&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B07145D93P</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wishlist</Description>
                    <URL>https://www.amazon.com/gp/registry/wishlist/add-item.html?asin.0=B07145D93P&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B07145D93P</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Tell A Friend</Description>
                    <URL>https://www.amazon.com/gp/pdp/taf/B07145D93P?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B07145D93P</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Customer Reviews</Description>
                    <URL>https://www.amazon.com/review/product/B07145D93P?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B07145D93P</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Offers</Description>
                    <URL>https://www.amazon.com/gp/offer-listing/B07145D93P?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B07145D93P</URL>
                </ItemLink>
            </ItemLinks>
            <SmallImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/61lRDVM9puL._SL75_.jpg</URL>
                <Height Units="pixels">75</Height>
                <Width Units="pixels">69</Width>
            </SmallImage>
            <MediumImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/61lRDVM9puL._SL160_.jpg</URL>
                <Height Units="pixels">160</Height>
                <Width Units="pixels">147</Width>
            </MediumImage>
            <LargeImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/61lRDVM9puL.jpg</URL>
                <Height Units="pixels">500</Height>
                <Width Units="pixels">458</Width>
            </LargeImage>
            <ImageSets>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/5121DtVJwxL._SL30_.jpg</URL>
                        <Height Units="pixels">20</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/5121DtVJwxL._SL75_.jpg</URL>
                        <Height Units="pixels">50</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/5121DtVJwxL._SL75_.jpg</URL>
                        <Height Units="pixels">50</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/5121DtVJwxL._SL110_.jpg</URL>
                        <Height Units="pixels">73</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/5121DtVJwxL._SL160_.jpg</URL>
                        <Height Units="pixels">107</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/5121DtVJwxL.jpg</URL>
                        <Height Units="pixels">333</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51FUZZH7hAL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">20</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51FUZZH7hAL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">50</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51FUZZH7hAL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">50</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51FUZZH7hAL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">73</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51FUZZH7hAL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">106</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51FUZZH7hAL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">332</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61KidsO0U8L._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">29</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61KidsO0U8L._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">72</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61KidsO0U8L._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">72</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61KidsO0U8L._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">106</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61KidsO0U8L._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">154</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61KidsO0U8L.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">481</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51%2Bqb84esVL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51%2Bqb84esVL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51%2Bqb84esVL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51%2Bqb84esVL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51%2Bqb84esVL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51%2Bqb84esVL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="primary">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61lRDVM9puL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">27</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61lRDVM9puL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">69</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61lRDVM9puL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">69</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61lRDVM9puL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">101</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61lRDVM9puL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">147</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61lRDVM9puL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">458</Width>
                    </LargeImage>
                </ImageSet>
            </ImageSets>
            <ItemAttributes>
                <Binding>Kitchen</Binding>
                <Brand>LA JOLIE MUSE</Brand>
                <Color>Terracotta Large</Color>
                <EAN>0716045050824</EAN>
                <EANList>
                    <EANListElement>0716045050824</EANListElement>
                </EANList>
                <Feature>★★★ 【Limited Offer】Regular price is $29.99. PRICE MAY INCREASE ANY TIME.</Feature>
                <Feature>★ STYLISH WAY TO ORGANIZE - Organizing doesn't have to be boring anymore! Our cotton basket doubles as art and storage. Consider it as a part of decorating your home to enhance its visuals.</Feature>
                <Feature>★LARGE SIZE- 15"H x 13"L x 13"W. NOTE- Our cotton baskets are brand new and produced in our very own factory with 100% pure cotton rope. When received you make notice some folds or dents, this can easily be smoothed out by storing the basket with items to return it to its original shape.</Feature>
                <Feature>★ COTTON ROPE & WEAVE- This basket is soft, but sturdy enough to maintain its shape no matter what goes inside. The pure cotton rope material makes it durable whilst giving it a handmade touch. Each basket includes handles for easy maneuvering around your home.</Feature>
                <Feature>★ VARIOUS USES - This handy dandy basket is the perfect solution for all of your storage needs. Put your laundry, books, toys, anything you want in this cotton rope basket, to tidy up your home with a pinch of modern style.</Feature>
                <IsAutographed>0</IsAutographed>
                <ItemDimensions>
                    <Height Units="hundredths-inches">1500</Height>
                    <Length Units="hundredths-inches">1300</Length>
                    <Weight Units="Hundredths Pounds">163</Weight>
                    <Width Units="hundredths-inches">1300</Width>
                </ItemDimensions>
                <Label>LA JOLIE MUSE</Label>
                <ListPrice>
                    <Amount>3800</Amount>
                    <CurrencyCode>USD</CurrencyCode>
                    <FormattedPrice>$38.00</FormattedPrice>
                </ListPrice>
                <Manufacturer>LA JOLIE MUSE</Manufacturer>
                <ManufacturerMinimumAge Units="months">1</ManufacturerMinimumAge>
                <MPN>LA JOLIE MUSE</MPN>
                <PackageDimensions>
                    <Height Units="hundredths-inches">150</Height>
                    <Length Units="hundredths-inches">1701</Length>
                    <Weight Units="Hundredths Pounds">161</Weight>
                    <Width Units="hundredths-inches">1299</Width>
                </PackageDimensions>
                <PartNumber>LA JOLIE MUSE</PartNumber>
                <ProductGroup>Baby Product</ProductGroup>
                <ProductTypeName>BABY_PRODUCT</ProductTypeName>
                <Publisher>LA JOLIE MUSE</Publisher>
                <Size>15" x 13" x 13"</Size>
                <Studio>LA JOLIE MUSE</Studio>
                <Title>Storage Baskets Large Terracotta Woven Basket, 15"x 13" Cotton Rope Decorative Baskets for Towel, Laundry, Magzine, Gift Basket</Title>
                <UPC>716045050824</UPC>
                <UPCList>
                    <UPCListElement>716045050824</UPCListElement>
                </UPCList>
            </ItemAttributes>
        </Item>
        <Item>
            <ASIN>B075W4P3K9</ASIN>
            <ParentASIN>B072L29RHN</ParentASIN>
            <DetailPageURL>https://www.amazon.com/DOKEHOM-DKA0611BNS2-Available-Drawstring-Collapsible/dp/B075W4P3K9?psc=1&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=165953&creativeASIN=B075W4P3K9</DetailPageURL>
            <ItemLinks>
                <ItemLink>
                    <Description>Technical Details</Description>
                    <URL>https://www.amazon.com/DOKEHOM-DKA0611BNS2-Available-Drawstring-Collapsible/dp/tech-data/B075W4P3K9?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B075W4P3K9</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Baby Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/baby/add-item.html?asin.0=B075W4P3K9&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B075W4P3K9</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wedding Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/wedding/add-item.html?asin.0=B075W4P3K9&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B075W4P3K9</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wishlist</Description>
                    <URL>https://www.amazon.com/gp/registry/wishlist/add-item.html?asin.0=B075W4P3K9&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B075W4P3K9</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Tell A Friend</Description>
                    <URL>https://www.amazon.com/gp/pdp/taf/B075W4P3K9?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B075W4P3K9</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Customer Reviews</Description>
                    <URL>https://www.amazon.com/review/product/B075W4P3K9?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B075W4P3K9</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Offers</Description>
                    <URL>https://www.amazon.com/gp/offer-listing/B075W4P3K9?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B075W4P3K9</URL>
                </ItemLink>
            </ItemLinks>
            <SmallImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/51asLQ21QsL._SL75_.jpg</URL>
                <Height Units="pixels">75</Height>
                <Width Units="pixels">75</Width>
            </SmallImage>
            <MediumImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/51asLQ21QsL._SL160_.jpg</URL>
                <Height Units="pixels">160</Height>
                <Width Units="pixels">160</Width>
            </MediumImage>
            <LargeImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/51asLQ21QsL.jpg</URL>
                <Height Units="pixels">500</Height>
                <Width Units="pixels">500</Width>
            </LargeImage>
            <ImageSets>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51xOXHsWzHL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51xOXHsWzHL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51xOXHsWzHL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51xOXHsWzHL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51xOXHsWzHL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51xOXHsWzHL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51KEDXpktDL._SL30_.jpg</URL>
                        <Height Units="pixels">21</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51KEDXpktDL._SL75_.jpg</URL>
                        <Height Units="pixels">51</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51KEDXpktDL._SL75_.jpg</URL>
                        <Height Units="pixels">51</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51KEDXpktDL._SL110_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51KEDXpktDL._SL160_.jpg</URL>
                        <Height Units="pixels">109</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51KEDXpktDL.jpg</URL>
                        <Height Units="pixels">342</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51U4CYFkOkL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">22</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51U4CYFkOkL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">54</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51U4CYFkOkL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">54</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51U4CYFkOkL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">79</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51U4CYFkOkL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">115</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51U4CYFkOkL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">360</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51KK%2BpMn8HL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51KK%2BpMn8HL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51KK%2BpMn8HL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51KK%2BpMn8HL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51KK%2BpMn8HL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51KK%2BpMn8HL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61BcZEaHrTL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">22</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61BcZEaHrTL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">56</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61BcZEaHrTL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">56</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61BcZEaHrTL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">82</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61BcZEaHrTL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">120</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61BcZEaHrTL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">375</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61ZV4-zxPIL._SL30_.jpg</URL>
                        <Height Units="pixels">22</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61ZV4-zxPIL._SL75_.jpg</URL>
                        <Height Units="pixels">56</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61ZV4-zxPIL._SL75_.jpg</URL>
                        <Height Units="pixels">56</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61ZV4-zxPIL._SL110_.jpg</URL>
                        <Height Units="pixels">82</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61ZV4-zxPIL._SL160_.jpg</URL>
                        <Height Units="pixels">120</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61ZV4-zxPIL.jpg</URL>
                        <Height Units="pixels">375</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51to0X8dtPL._SL30_.jpg</URL>
                        <Height Units="pixels">25</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51to0X8dtPL._SL75_.jpg</URL>
                        <Height Units="pixels">63</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51to0X8dtPL._SL75_.jpg</URL>
                        <Height Units="pixels">63</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51to0X8dtPL._SL110_.jpg</URL>
                        <Height Units="pixels">92</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51to0X8dtPL._SL160_.jpg</URL>
                        <Height Units="pixels">134</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51to0X8dtPL.jpg</URL>
                        <Height Units="pixels">418</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="primary">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51asLQ21QsL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51asLQ21QsL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51asLQ21QsL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51asLQ21QsL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51asLQ21QsL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51asLQ21QsL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
            </ImageSets>
            <ItemAttributes>
                <Binding>Kitchen</Binding>
                <Brand>DOKEHOM</Brand>
                <Color>Brown Dots</Color>
                <EAN>0689749273939</EAN>
                <EANList>
                    <EANListElement>0689749273939</EANListElement>
                </EANList>
                <Feature>Folding storage basket, very lightweight and easy to carry away.</Feature>
                <Feature>Drawstring closure for dust-proof.</Feature>
                <Feature>Dimensions: 15"x10.2"x10.2" (38x26x26cm) approx.</Feature>
                <Feature>Material: 100% cotton with PE coating inside for waterproof.</Feature>
                <Feature>Perfect storage tool for book, toy, clothes, etc.</Feature>
                <IsAutographed>0</IsAutographed>
                <ItemDimensions>
                    <Height Units="hundredths-inches">59</Height>
                    <Length Units="hundredths-inches">1575</Length>
                    <Weight Units="Hundredths Pounds">44</Weight>
                    <Width Units="hundredths-inches">1181</Width>
                </ItemDimensions>
                <Label>IMOTECH TECHNOLOGY</Label>
                <ListPrice>
                    <Amount>999</Amount>
                    <CurrencyCode>USD</CurrencyCode>
                    <FormattedPrice>$9.99</FormattedPrice>
                </ListPrice>
                <Manufacturer>IMOTECH TECHNOLOGY</Manufacturer>
                <MPN>DKA0611BNS2</MPN>
                <PackageDimensions>
                    <Height Units="hundredths-inches">146</Height>
                    <Length Units="hundredths-inches">1614</Length>
                    <Weight Units="Hundredths Pounds">55</Weight>
                    <Width Units="hundredths-inches">1217</Width>
                </PackageDimensions>
                <PartNumber>DKA0611BNS2</PartNumber>
                <ProductGroup>Home</ProductGroup>
                <ProductTypeName>HOME_FURNITURE_AND_DECOR</ProductTypeName>
                <Publisher>IMOTECH TECHNOLOGY</Publisher>
                <Size>15"/Medium</Size>
                <Studio>IMOTECH TECHNOLOGY</Studio>
                <Title>DOKEHOM DKA0611BNS2 15" Large Storage Basket (Available 15" and 17"), Drawstring Square Cotton Linen Collapsible Toy Basket (Brown, M)</Title>
                <UPC>689749273939</UPC>
                <UPCList>
                    <UPCListElement>689749273939</UPCListElement>
                </UPCList>
            </ItemAttributes>
        </Item>
        <Item>
            <ASIN>B0081STHQQ</ASIN>
            <DetailPageURL>https://www.amazon.com/Vintiquewise-QI003055-WF-Willow-Basket-Handles/dp/B0081STHQQ?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=165953&creativeASIN=B0081STHQQ</DetailPageURL>
            <ItemLinks>
                <ItemLink>
                    <Description>Technical Details</Description>
                    <URL>https://www.amazon.com/Vintiquewise-QI003055-WF-Willow-Basket-Handles/dp/tech-data/B0081STHQQ?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B0081STHQQ</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Baby Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/baby/add-item.html?asin.0=B0081STHQQ&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B0081STHQQ</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wedding Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/wedding/add-item.html?asin.0=B0081STHQQ&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B0081STHQQ</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wishlist</Description>
                    <URL>https://www.amazon.com/gp/registry/wishlist/add-item.html?asin.0=B0081STHQQ&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B0081STHQQ</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Tell A Friend</Description>
                    <URL>https://www.amazon.com/gp/pdp/taf/B0081STHQQ?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B0081STHQQ</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Customer Reviews</Description>
                    <URL>https://www.amazon.com/review/product/B0081STHQQ?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B0081STHQQ</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Offers</Description>
                    <URL>https://www.amazon.com/gp/offer-listing/B0081STHQQ?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B0081STHQQ</URL>
                </ItemLink>
            </ItemLinks>
            <SmallImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/41pje5SyDjL._SL75_.jpg</URL>
                <Height Units="pixels">62</Height>
                <Width Units="pixels">75</Width>
            </SmallImage>
            <MediumImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/41pje5SyDjL._SL160_.jpg</URL>
                <Height Units="pixels">133</Height>
                <Width Units="pixels">160</Width>
            </MediumImage>
            <LargeImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/41pje5SyDjL.jpg</URL>
                <Height Units="pixels">416</Height>
                <Width Units="pixels">500</Width>
            </LargeImage>
            <ImageSets>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51nlKSi7C4L._SL30_.jpg</URL>
                        <Height Units="pixels">21</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51nlKSi7C4L._SL75_.jpg</URL>
                        <Height Units="pixels">53</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51nlKSi7C4L._SL75_.jpg</URL>
                        <Height Units="pixels">53</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51nlKSi7C4L._SL110_.jpg</URL>
                        <Height Units="pixels">77</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51nlKSi7C4L._SL160_.jpg</URL>
                        <Height Units="pixels">112</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51nlKSi7C4L.jpg</URL>
                        <Height Units="pixels">351</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51rIy3KZ0ZL._SL30_.jpg</URL>
                        <Height Units="pixels">26</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51rIy3KZ0ZL._SL75_.jpg</URL>
                        <Height Units="pixels">66</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51rIy3KZ0ZL._SL75_.jpg</URL>
                        <Height Units="pixels">66</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51rIy3KZ0ZL._SL110_.jpg</URL>
                        <Height Units="pixels">97</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51rIy3KZ0ZL._SL160_.jpg</URL>
                        <Height Units="pixels">141</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51rIy3KZ0ZL.jpg</URL>
                        <Height Units="pixels">441</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51gCTNr9W7L._SL30_.jpg</URL>
                        <Height Units="pixels">25</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51gCTNr9W7L._SL75_.jpg</URL>
                        <Height Units="pixels">62</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51gCTNr9W7L._SL75_.jpg</URL>
                        <Height Units="pixels">62</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51gCTNr9W7L._SL110_.jpg</URL>
                        <Height Units="pixels">91</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51gCTNr9W7L._SL160_.jpg</URL>
                        <Height Units="pixels">132</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51gCTNr9W7L.jpg</URL>
                        <Height Units="pixels">414</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="primary">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41pje5SyDjL._SL30_.jpg</URL>
                        <Height Units="pixels">25</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41pje5SyDjL._SL75_.jpg</URL>
                        <Height Units="pixels">62</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41pje5SyDjL._SL75_.jpg</URL>
                        <Height Units="pixels">62</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41pje5SyDjL._SL110_.jpg</URL>
                        <Height Units="pixels">92</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41pje5SyDjL._SL160_.jpg</URL>
                        <Height Units="pixels">133</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41pje5SyDjL.jpg</URL>
                        <Height Units="pixels">416</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
            </ImageSets>
            <ItemAttributes>
                <Binding>Lawn & Patio</Binding>
                <Brand>Vintiquewise</Brand>
                <Color>White</Color>
                <EAN>5133330323367</EAN>
                <EANList>
                    <EANListElement>5133330323367</EANListElement>
                    <EANListElement>5557890045390</EANListElement>
                    <EANListElement>5662252302698</EANListElement>
                    <EANListElement>0651355220775</EANListElement>
                    <EANListElement>6942469361022</EANListElement>
                    <EANListElement>6966677951547</EANListElement>
                </EANList>
                <Feature>2 handles for easy carrying</Feature>
                <Feature>Attractive and elegant lined basket</Feature>
                <Feature>Practical and handy addition to any home</Feature>
                <Feature>Approx. Dimension: 13" x 10.25" x 4.75"</Feature>
                <IsAutographed>0</IsAutographed>
                <ItemDimensions>
                    <Height Units="hundredths-inches">470</Height>
                    <Length Units="hundredths-inches">1300</Length>
                    <Weight Units="Pounds">0.3</Weight>
                    <Width Units="hundredths-inches">1020</Width>
                </ItemDimensions>
                <Label>Quickway Imports Inc</Label>
                <ListPrice>
                    <Amount>3500</Amount>
                    <CurrencyCode>USD</CurrencyCode>
                    <FormattedPrice>$35.00</FormattedPrice>
                </ListPrice>
                <Manufacturer>Quickway Imports Inc</Manufacturer>
                <Model>QI003055W</Model>
                <MPN>QI003055W</MPN>
                <NumberOfItems>1</NumberOfItems>
                <PackageDimensions>
                    <Height Units="hundredths-inches">570</Height>
                    <Length Units="hundredths-inches">1300</Length>
                    <Weight Units="Hundredths Pounds">30</Weight>
                    <Width Units="hundredths-inches">1040</Width>
                </PackageDimensions>
                <PackageQuantity>1</PackageQuantity>
                <PartNumber>QI003055W</PartNumber>
                <ProductGroup>Lawn & Patio</ProductGroup>
                <ProductTypeName>OUTDOOR_LIVING</ProductTypeName>
                <Publisher>Quickway Imports Inc</Publisher>
                <ReleaseDate>2014-04-24</ReleaseDate>
                <Studio>Quickway Imports Inc</Studio>
                <Title>Vintiquewise(TM) QI003055.WF Oval Willow Basket with Double Drop Down Handles</Title>
                <UPC>651355220775</UPC>
                <UPCList>
                    <UPCListElement>651355220775</UPCListElement>
                </UPCList>
            </ItemAttributes>
        </Item>
        <Item>
            <ASIN>B00I01AWVS</ASIN>
            <ParentASIN>B079YNXJR3</ParentASIN>
            <DetailPageURL>https://www.amazon.com/Whitmor-Woven-Strap-Small-Liner/dp/B00I01AWVS?psc=1&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=165953&creativeASIN=B00I01AWVS</DetailPageURL>
            <ItemLinks>
                <ItemLink>
                    <Description>Technical Details</Description>
                    <URL>https://www.amazon.com/Whitmor-Woven-Strap-Small-Liner/dp/tech-data/B00I01AWVS?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B00I01AWVS</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Baby Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/baby/add-item.html?asin.0=B00I01AWVS&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B00I01AWVS</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wedding Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/wedding/add-item.html?asin.0=B00I01AWVS&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B00I01AWVS</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wishlist</Description>
                    <URL>https://www.amazon.com/gp/registry/wishlist/add-item.html?asin.0=B00I01AWVS&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B00I01AWVS</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Tell A Friend</Description>
                    <URL>https://www.amazon.com/gp/pdp/taf/B00I01AWVS?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B00I01AWVS</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Customer Reviews</Description>
                    <URL>https://www.amazon.com/review/product/B00I01AWVS?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B00I01AWVS</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Offers</Description>
                    <URL>https://www.amazon.com/gp/offer-listing/B00I01AWVS?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B00I01AWVS</URL>
                </ItemLink>
            </ItemLinks>
            <SmallImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/41DdrwWVcnL._SL75_.jpg</URL>
                <Height Units="pixels">49</Height>
                <Width Units="pixels">75</Width>
            </SmallImage>
            <MediumImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/41DdrwWVcnL._SL160_.jpg</URL>
                <Height Units="pixels">105</Height>
                <Width Units="pixels">160</Width>
            </MediumImage>
            <LargeImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/41DdrwWVcnL.jpg</URL>
                <Height Units="pixels">328</Height>
                <Width Units="pixels">500</Width>
            </LargeImage>
            <ImageSets>
                <ImageSet Category="primary">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41DdrwWVcnL._SL30_.jpg</URL>
                        <Height Units="pixels">20</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41DdrwWVcnL._SL75_.jpg</URL>
                        <Height Units="pixels">49</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41DdrwWVcnL._SL75_.jpg</URL>
                        <Height Units="pixels">49</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41DdrwWVcnL._SL110_.jpg</URL>
                        <Height Units="pixels">72</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41DdrwWVcnL._SL160_.jpg</URL>
                        <Height Units="pixels">105</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41DdrwWVcnL.jpg</URL>
                        <Height Units="pixels">328</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
            </ImageSets>
            <ItemAttributes>
                <Binding>Misc.</Binding>
                <Brand>Whitmor</Brand>
                <Color>Brown</Color>
                <EAN>0885550419706</EAN>
                <EANList>
                    <EANListElement>0885550419706</EANListElement>
                    <EANListElement>0787543881746</EANListElement>
                    <EANListElement>0038861096221</EANListElement>
                </EANList>
                <Feature>Durable construction of stain resistant wipe clean woven strapping with epoxy coated metal frame</Feature>
                <Feature>Storage containers with sewn-in handles for easy transport</Feature>
                <Feature>Dimensions: 14.42" x 6.5" x 4.53"</Feature>
                <Feature>Tuck baskets away in closets, storage cubes or on a shelf for extra storage. Use for clothing, bath & beauty products, toys, school supplies & more</Feature>
                <Feature>Decorative woven totes blend seamlessly into any room of your home or perfect for multipurpose use in cafes, restaurants & offices.</Feature>
                <Feature>Great for small linens, bath and beauty products, toys, school supplies, magazines and more</Feature>
                <Feature>Mix & Match for stylish storage. Whitmor storage containers come in a variety of colors and sizes</Feature>
                <Feature>Service & Guarantee: Whitmor stands by our products. If you have any problems, contact us for help</Feature>
                <IsAutographed>0</IsAutographed>
                <ItemDimensions>
                    <Height Units="hundredths-inches">453</Height>
                    <Length Units="hundredths-inches">650</Length>
                    <Weight Units="Pounds">1</Weight>
                    <Width Units="hundredths-inches">650</Width>
                </ItemDimensions>
                <Label>Whitmor</Label>
                <ListPrice>
                    <Amount>1299</Amount>
                    <CurrencyCode>USD</CurrencyCode>
                    <FormattedPrice>$12.99</FormattedPrice>
                </ListPrice>
                <Manufacturer>Whitmor</Manufacturer>
                <Model>6581-3922-ESPR</Model>
                <MPN>6581-3922-ESPR</MPN>
                <NumberOfItems>1</NumberOfItems>
                <PackageDimensions>
                    <Height Units="hundredths-inches">430</Height>
                    <Length Units="hundredths-inches">1140</Length>
                    <Weight Units="Hundredths Pounds">75</Weight>
                    <Width Units="hundredths-inches">640</Width>
                </PackageDimensions>
                <PackageQuantity>1</PackageQuantity>
                <PartNumber>6581-3922-ESPR</PartNumber>
                <ProductGroup>Home</ProductGroup>
                <ProductTypeName>HOME</ProductTypeName>
                <Publisher>Whitmor</Publisher>
                <Size>SMALL SHELF TOTE W/LINER</Size>
                <Studio>Whitmor</Studio>
                <Title>Whitmor Woven Strap Small Tote w/ Liner</Title>
                <UPC>787543881746</UPC>
                <UPCList>
                    <UPCListElement>787543881746</UPCListElement>
                    <UPCListElement>038861096221</UPCListElement>
                    <UPCListElement>885550419706</UPCListElement>
                </UPCList>
            </ItemAttributes>
        </Item>
        <Item>
            <ASIN>B06W5C5KBT</ASIN>
            <ParentASIN>B06X977QBV</ParentASIN>
            <DetailPageURL>https://www.amazon.com/Foldable-Waterproof-Organizer-Collapsible-Convenient/dp/B06W5C5KBT?psc=1&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=165953&creativeASIN=B06W5C5KBT</DetailPageURL>
            <ItemLinks>
                <ItemLink>
                    <Description>Technical Details</Description>
                    <URL>https://www.amazon.com/Foldable-Waterproof-Organizer-Collapsible-Convenient/dp/tech-data/B06W5C5KBT?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B06W5C5KBT</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Baby Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/baby/add-item.html?asin.0=B06W5C5KBT&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B06W5C5KBT</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wedding Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/wedding/add-item.html?asin.0=B06W5C5KBT&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B06W5C5KBT</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wishlist</Description>
                    <URL>https://www.amazon.com/gp/registry/wishlist/add-item.html?asin.0=B06W5C5KBT&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B06W5C5KBT</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Tell A Friend</Description>
                    <URL>https://www.amazon.com/gp/pdp/taf/B06W5C5KBT?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B06W5C5KBT</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Customer Reviews</Description>
                    <URL>https://www.amazon.com/review/product/B06W5C5KBT?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B06W5C5KBT</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Offers</Description>
                    <URL>https://www.amazon.com/gp/offer-listing/B06W5C5KBT?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B06W5C5KBT</URL>
                </ItemLink>
            </ItemLinks>
            <SmallImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/51dypTdRQHL._SL75_.jpg</URL>
                <Height Units="pixels">75</Height>
                <Width Units="pixels">75</Width>
            </SmallImage>
            <MediumImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/51dypTdRQHL._SL160_.jpg</URL>
                <Height Units="pixels">160</Height>
                <Width Units="pixels">160</Width>
            </MediumImage>
            <LargeImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/51dypTdRQHL.jpg</URL>
                <Height Units="pixels">500</Height>
                <Width Units="pixels">500</Width>
            </LargeImage>
            <ImageSets>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51ggerbFBZL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51ggerbFBZL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51ggerbFBZL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51ggerbFBZL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51ggerbFBZL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51ggerbFBZL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51ATPw7NW0L._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51ATPw7NW0L._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51ATPw7NW0L._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51ATPw7NW0L._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51ATPw7NW0L._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51ATPw7NW0L.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41Ku5xkDUNL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41Ku5xkDUNL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41Ku5xkDUNL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41Ku5xkDUNL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41Ku5xkDUNL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41Ku5xkDUNL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51ZEpQab2aL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51ZEpQab2aL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51ZEpQab2aL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51ZEpQab2aL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51ZEpQab2aL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51ZEpQab2aL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51D7XcFSqtL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51D7XcFSqtL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51D7XcFSqtL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51D7XcFSqtL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51D7XcFSqtL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51D7XcFSqtL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/418ySIFlcML._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/418ySIFlcML._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/418ySIFlcML._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/418ySIFlcML._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/418ySIFlcML._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/418ySIFlcML.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41BQ1SrVhCL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41BQ1SrVhCL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41BQ1SrVhCL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41BQ1SrVhCL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41BQ1SrVhCL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41BQ1SrVhCL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="primary">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51dypTdRQHL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51dypTdRQHL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51dypTdRQHL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51dypTdRQHL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51dypTdRQHL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51dypTdRQHL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
            </ImageSets>
            <ItemAttributes>
                <Binding>Baby Product</Binding>
                <Brand>USATDD</Brand>
                <Color>Grey</Color>
                <EAN>0602456750029</EAN>
                <EANList>
                    <EANListElement>0602456750029</EANListElement>
                </EANList>
                <Feature>✅ MADE TO LAST - Made of 100% Cotton Linen Canvas material with two strong handles on the sides.Warm cotton and linen material,storage all kinds of desktop small items, with simple and fashion breath, let your home full of natural beauty.</Feature>
                <Feature>✅ WELL SIZED - Basket size 7.8"×6.3"×5.1",please confirm the size whether you need before purchase.</Feature>
                <Feature>✅ WATERPROOF AND COLLAPSIBLE - The back is waterproof coating. Lightweight and compact in size, basket folds down for easy storage while not in use.</Feature>
                <Feature>✅ VERSATILE AND FASHION SHAPE-It will be the Best Storage Basket for your Books, Magazine, CD, DVDS, Balls, Cellphone, Earphone, Chargers, Cables, Cosmetics, Makeup, Keys, Cards, Snacks, Towels, Clothes, Underwear, Bra, Socks, Kids Toys, Diapers, Dog Toys, and so on.</Feature>
                <Feature>✅ 100% SATISFACTION - 100% Money Back Guarantee.</Feature>
                <IsAdultProduct>0</IsAdultProduct>
                <ItemDimensions>
                    <Height Units="hundredths-inches">130</Height>
                    <Length Units="hundredths-inches">831</Length>
                    <Weight Units="Hundredths Pounds">20</Weight>
                    <Width Units="hundredths-inches">681</Width>
                </ItemDimensions>
                <Label>USATDD</Label>
                <ListPrice>
                    <Amount>1499</Amount>
                    <CurrencyCode>USD</CurrencyCode>
                    <FormattedPrice>$14.99</FormattedPrice>
                </ListPrice>
                <Manufacturer>USATDD</Manufacturer>
                <ManufacturerMaximumAge Units="months">1188</ManufacturerMaximumAge>
                <ManufacturerMinimumAge Units="months">6</ManufacturerMinimumAge>
                <MPN>TDDB0008</MPN>
                <PackageDimensions>
                    <Height Units="hundredths-inches">75</Height>
                    <Length Units="hundredths-inches">827</Length>
                    <Weight Units="Hundredths Pounds">19</Weight>
                    <Width Units="hundredths-inches">650</Width>
                </PackageDimensions>
                <PackageQuantity>1</PackageQuantity>
                <PartNumber>TDDB0008</PartNumber>
                <ProductGroup>Baby Product</ProductGroup>
                <ProductTypeName>BABY_PRODUCT</ProductTypeName>
                <Publisher>USATDD</Publisher>
                <Size>Small</Size>
                <Studio>USATDD</Studio>
                <Title>Small Foldable Storage Basket Canvas Fabric Waterproof Organizer Collapsible and Convenient For Nursery Babies Room 100% COTTON with Handle (Grey)</Title>
                <UPC>602456750029</UPC>
                <UPCList>
                    <UPCListElement>602456750029</UPCListElement>
                </UPCList>
            </ItemAttributes>
        </Item>
        <Item>
            <ASIN>B076DHYQM1</ASIN>
            <DetailPageURL>https://www.amazon.com/Large-Woven-Seagrass-Storage-Basket/dp/B076DHYQM1?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=165953&creativeASIN=B076DHYQM1</DetailPageURL>
            <ItemLinks>
                <ItemLink>
                    <Description>Technical Details</Description>
                    <URL>https://www.amazon.com/Large-Woven-Seagrass-Storage-Basket/dp/tech-data/B076DHYQM1?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B076DHYQM1</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Baby Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/baby/add-item.html?asin.0=B076DHYQM1&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B076DHYQM1</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wedding Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/wedding/add-item.html?asin.0=B076DHYQM1&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B076DHYQM1</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wishlist</Description>
                    <URL>https://www.amazon.com/gp/registry/wishlist/add-item.html?asin.0=B076DHYQM1&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B076DHYQM1</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Tell A Friend</Description>
                    <URL>https://www.amazon.com/gp/pdp/taf/B076DHYQM1?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B076DHYQM1</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Customer Reviews</Description>
                    <URL>https://www.amazon.com/review/product/B076DHYQM1?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B076DHYQM1</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Offers</Description>
                    <URL>https://www.amazon.com/gp/offer-listing/B076DHYQM1?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B076DHYQM1</URL>
                </ItemLink>
            </ItemLinks>
            <SmallImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/51hYJjXzmLL._SL75_.jpg</URL>
                <Height Units="pixels">75</Height>
                <Width Units="pixels">75</Width>
            </SmallImage>
            <MediumImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/51hYJjXzmLL._SL160_.jpg</URL>
                <Height Units="pixels">160</Height>
                <Width Units="pixels">160</Width>
            </MediumImage>
            <LargeImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/51hYJjXzmLL.jpg</URL>
                <Height Units="pixels">500</Height>
                <Width Units="pixels">500</Width>
            </LargeImage>
            <ImageSets>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/617SnPeJMBL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/617SnPeJMBL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/617SnPeJMBL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/617SnPeJMBL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/617SnPeJMBL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/617SnPeJMBL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51bp7YLzplL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51bp7YLzplL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51bp7YLzplL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51bp7YLzplL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51bp7YLzplL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51bp7YLzplL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51AfFntGLoL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51AfFntGLoL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51AfFntGLoL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51AfFntGLoL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51AfFntGLoL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51AfFntGLoL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/5170EjmDmnL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/5170EjmDmnL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/5170EjmDmnL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/5170EjmDmnL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/5170EjmDmnL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/5170EjmDmnL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51BFVQuug4L._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51BFVQuug4L._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51BFVQuug4L._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51BFVQuug4L._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51BFVQuug4L._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51BFVQuug4L.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="primary">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51hYJjXzmLL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51hYJjXzmLL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51hYJjXzmLL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51hYJjXzmLL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51hYJjXzmLL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51hYJjXzmLL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
            </ImageSets>
            <ItemAttributes>
                <Binding>Kitchen</Binding>
                <Brand>West Dwelling</Brand>
                <Color>Brown</Color>
                <EAN>0822415627135</EAN>
                <EANList>
                    <EANListElement>0822415627135</EANListElement>
                </EANList>
                <Feature>SAFE & SOFT NON-TOXIC NATURAL WATER HYACINTH - Made with natural water hyacinth, also known as seagrass, in a fashionable and stylish wicker pattern. Soft and durable to last for years to come!</Feature>
                <Feature>MULTI-PURPOSE USE - Our big natural woven baskets are a perfect storage for newspapers, pillows, blankets, towels, toys, board games, shoes, even as a laundry hamper, and these baskets are great even as a coastal decorative accent for any home!</Feature>
                <Feature>PORTABLE & LIGHTWEIGHT WITH TWO HANDLES - Easily transport or carry our lightweight baskets with an open top to any living room or nursery, useful for babies, boys, girls, and for the whole family!</Feature>
                <Feature>EACH BASKET UNIQUELY MADE IN VIETNAM - Seagrass baskets are individually handmade from Vietnam, so each basket is uniquely stylish and personal to each of our customers. Approximate size: 19" Length x 16" Width x 19" Height.</Feature>
                <Feature>AMERICAN SERVICE & SUPPORT - As a small family business, we stand by our quality and 2-year warranty. Should you ever have an issue with our storage baskets, we will replace it 100% free of charge!</Feature>
                <IsAutographed>0</IsAutographed>
                <ItemDimensions>
                    <Weight Units="Hundredths Pounds">240</Weight>
                </ItemDimensions>
                <Label>Chesed Products</Label>
                <ListPrice>
                    <Amount>4995</Amount>
                    <CurrencyCode>USD</CurrencyCode>
                    <FormattedPrice>$49.95</FormattedPrice>
                </ListPrice>
                <Manufacturer>Chesed Products</Manufacturer>
                <Model>並行輸入品</Model>
                <MPN>並行輸入品</MPN>
                <PackageDimensions>
                    <Height Units="hundredths-inches">1100</Height>
                    <Length Units="hundredths-inches">2150</Length>
                    <Weight Units="Hundredths Pounds">235</Weight>
                    <Width Units="hundredths-inches">1900</Width>
                </PackageDimensions>
                <PartNumber>並行輸入品</PartNumber>
                <ProductGroup>Home</ProductGroup>
                <ProductTypeName>HOME</ProductTypeName>
                <Publisher>Chesed Products</Publisher>
                <Studio>Chesed Products</Studio>
                <Title>Large Woven Seagrass Storage Basket – Wicker Pattern Baskets With Braided Handles As Organizer For Blankets, Towels, Pillows, Toys, Laundry, Baby, Kids, Home Decor - Natural Water Hyacinth</Title>
                <UPC>822415627135</UPC>
                <UPCList>
                    <UPCListElement>822415627135</UPCListElement>
                </UPCList>
            </ItemAttributes>
        </Item>
        <Item>
            <ASIN>B01MCYSBL6</ASIN>
            <ParentASIN>B078SD35J3</ParentASIN>
            <DetailPageURL>https://www.amazon.com/Collapsible-Storage-EZOWare-Foldable-Handles/dp/B01MCYSBL6?psc=1&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=165953&creativeASIN=B01MCYSBL6</DetailPageURL>
            <ItemLinks>
                <ItemLink>
                    <Description>Technical Details</Description>
                    <URL>https://www.amazon.com/Collapsible-Storage-EZOWare-Foldable-Handles/dp/tech-data/B01MCYSBL6?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01MCYSBL6</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Baby Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/baby/add-item.html?asin.0=B01MCYSBL6&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01MCYSBL6</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wedding Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/wedding/add-item.html?asin.0=B01MCYSBL6&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01MCYSBL6</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wishlist</Description>
                    <URL>https://www.amazon.com/gp/registry/wishlist/add-item.html?asin.0=B01MCYSBL6&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01MCYSBL6</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Tell A Friend</Description>
                    <URL>https://www.amazon.com/gp/pdp/taf/B01MCYSBL6?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01MCYSBL6</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Customer Reviews</Description>
                    <URL>https://www.amazon.com/review/product/B01MCYSBL6?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01MCYSBL6</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Offers</Description>
                    <URL>https://www.amazon.com/gp/offer-listing/B01MCYSBL6?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01MCYSBL6</URL>
                </ItemLink>
            </ItemLinks>
            <SmallImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/51qtf9WDTaL._SL75_.jpg</URL>
                <Height Units="pixels">75</Height>
                <Width Units="pixels">75</Width>
            </SmallImage>
            <MediumImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/51qtf9WDTaL._SL160_.jpg</URL>
                <Height Units="pixels">160</Height>
                <Width Units="pixels">160</Width>
            </MediumImage>
            <LargeImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/51qtf9WDTaL.jpg</URL>
                <Height Units="pixels">500</Height>
                <Width Units="pixels">500</Width>
            </LargeImage>
            <ImageSets>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51PPQODNIML._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51PPQODNIML._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51PPQODNIML._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51PPQODNIML._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51PPQODNIML._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51PPQODNIML.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/6183cK%2BwXAL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/6183cK%2BwXAL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/6183cK%2BwXAL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/6183cK%2BwXAL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/6183cK%2BwXAL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/6183cK%2BwXAL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/511AGwBi8BL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/511AGwBi8BL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/511AGwBi8BL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/511AGwBi8BL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/511AGwBi8BL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/511AGwBi8BL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61mZzv5uNdL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61mZzv5uNdL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61mZzv5uNdL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61mZzv5uNdL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61mZzv5uNdL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61mZzv5uNdL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51aHEjoXntL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51aHEjoXntL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51aHEjoXntL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51aHEjoXntL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51aHEjoXntL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51aHEjoXntL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61isr6udCgL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61isr6udCgL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61isr6udCgL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61isr6udCgL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61isr6udCgL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/61isr6udCgL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51yCFbESLBL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51yCFbESLBL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51yCFbESLBL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51yCFbESLBL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51yCFbESLBL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51yCFbESLBL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/511VLc682XL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/511VLc682XL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/511VLc682XL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/511VLc682XL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/511VLc682XL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/511VLc682XL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="primary">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51qtf9WDTaL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51qtf9WDTaL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51qtf9WDTaL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51qtf9WDTaL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51qtf9WDTaL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51qtf9WDTaL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
            </ImageSets>
            <ItemAttributes>
                <Binding>Kitchen</Binding>
                <Brand>EZOWare</Brand>
                <Color>Brown</Color>
                <EAN>0885157978507</EAN>
                <EANList>
                    <EANListElement>0885157978507</EANListElement>
                </EANList>
                <Feature>EZOWare Storage Bins are a perfect way to accessorize, organize, and store items at home, office, home office, loft or other dwellings. We offer storage solutions that complement lifestyles.</Feature>
                <Feature>Constructed of durable and attractive jute, cotton & PVE lining with linen interior lining. Metal eyelets and sturdy handle make it easy to carry or pull off and out of shelves.</Feature>
                <Feature>Fashionable Bins: Designed to match interior decor and style in any room in the home or office. Enjoy the relaxing ambiance of the soft gray and natural beige neutral color scheme.</Feature>
                <Feature>Utilize as closet organization bins, clothes baskets, child / kid room toy storage, living room sundry storage, cat & dog toy storage, book and magazine organizer, file organizer, bathroom towel and toilet storage, and many other uses.</Feature>
                <Feature>Set of 3, for better value and shopping convenience. Dimensions (each): 15 (L) x 10.6 (W) x 9.4 (H) inches (38 x 27 x 24cm). Material: twill, cotton, polyester.</Feature>
                <IsAdultProduct>0</IsAdultProduct>
                <IsAutographed>0</IsAutographed>
                <ItemDimensions>
                    <Height Units="hundredths-inches">1060</Height>
                    <Length Units="hundredths-inches">1500</Length>
                    <Weight Units="Hundredths Pounds">157</Weight>
                    <Width Units="hundredths-inches">940</Width>
                </ItemDimensions>
                <Label>EZOWare</Label>
                <ListPrice>
                    <Amount>2399</Amount>
                    <CurrencyCode>USD</CurrencyCode>
                    <FormattedPrice>$23.99</FormattedPrice>
                </ListPrice>
                <Manufacturer>EZOWare</Manufacturer>
                <ManufacturerMinimumAge Units="months">0</ManufacturerMinimumAge>
                <MPN>885157978507</MPN>
                <PackageDimensions>
                    <Height Units="hundredths-inches">358</Height>
                    <Length Units="hundredths-inches">1579</Length>
                    <Weight Units="Hundredths Pounds">155</Weight>
                    <Width Units="hundredths-inches">1031</Width>
                </PackageDimensions>
                <PackageQuantity>3</PackageQuantity>
                <PartNumber>885157978507</PartNumber>
                <ProductGroup>Baby Product</ProductGroup>
                <ProductTypeName>BABY_PRODUCT</ProductTypeName>
                <Publisher>EZOWare</Publisher>
                <Size>15 (L) x 10.6 (W) x 9.4 (H) inches (38 x 27 x 24cm</Size>
                <Studio>EZOWare</Studio>
                <Title>Collapsible Storage Bin Basket [3-Pack] EZOWare Foldable Canvas Fabric Tweed Storage Cube Bin Set With Handles - Brown / Gray For Home Office Closet</Title>
                <UPC>885157978507</UPC>
                <UPCList>
                    <UPCListElement>885157978507</UPCListElement>
                </UPCList>
            </ItemAttributes>
        </Item>
        <Item>
            <ASIN>B01HNLL9M6</ASIN>
            <DetailPageURL>https://www.amazon.com/Tosnail-Essentials-Collapsible-Convenient-Storage/dp/B01HNLL9M6?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=165953&creativeASIN=B01HNLL9M6</DetailPageURL>
            <ItemLinks>
                <ItemLink>
                    <Description>Technical Details</Description>
                    <URL>https://www.amazon.com/Tosnail-Essentials-Collapsible-Convenient-Storage/dp/tech-data/B01HNLL9M6?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01HNLL9M6</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Baby Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/baby/add-item.html?asin.0=B01HNLL9M6&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01HNLL9M6</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wedding Registry</Description>
                    <URL>https://www.amazon.com/gp/registry/wedding/add-item.html?asin.0=B01HNLL9M6&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01HNLL9M6</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Add To Wishlist</Description>
                    <URL>https://www.amazon.com/gp/registry/wishlist/add-item.html?asin.0=B01HNLL9M6&SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01HNLL9M6</URL>
                </ItemLink>
                <ItemLink>
                    <Description>Tell A Friend</Description>
                    <URL>https://www.amazon.com/gp/pdp/taf/B01HNLL9M6?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01HNLL9M6</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Customer Reviews</Description>
                    <URL>https://www.amazon.com/review/product/B01HNLL9M6?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01HNLL9M6</URL>
                </ItemLink>
                <ItemLink>
                    <Description>All Offers</Description>
                    <URL>https://www.amazon.com/gp/offer-listing/B01HNLL9M6?SubscriptionId=AKIAIEPGTWIXGRZC2NVQ&tag=ellieage-20&linkCode=xm2&camp=2025&creative=386001&creativeASIN=B01HNLL9M6</URL>
                </ItemLink>
            </ItemLinks>
            <SmallImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/410VNyMfaOL._SL75_.jpg</URL>
                <Height Units="pixels">75</Height>
                <Width Units="pixels">75</Width>
            </SmallImage>
            <MediumImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/410VNyMfaOL._SL160_.jpg</URL>
                <Height Units="pixels">160</Height>
                <Width Units="pixels">160</Width>
            </MediumImage>
            <LargeImage>
                <URL>https://images-na.ssl-images-amazon.com/images/I/410VNyMfaOL.jpg</URL>
                <Height Units="pixels">500</Height>
                <Width Units="pixels">500</Width>
            </LargeImage>
            <ImageSets>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41BVxarKizL._SL30_.jpg</URL>
                        <Height Units="pixels">20</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41BVxarKizL._SL75_.jpg</URL>
                        <Height Units="pixels">50</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41BVxarKizL._SL75_.jpg</URL>
                        <Height Units="pixels">50</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41BVxarKizL._SL110_.jpg</URL>
                        <Height Units="pixels">73</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41BVxarKizL._SL160_.jpg</URL>
                        <Height Units="pixels">107</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/41BVxarKizL.jpg</URL>
                        <Height Units="pixels">333</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51NDUikFCjL._SL30_.jpg</URL>
                        <Height Units="pixels">20</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51NDUikFCjL._SL75_.jpg</URL>
                        <Height Units="pixels">50</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51NDUikFCjL._SL75_.jpg</URL>
                        <Height Units="pixels">50</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51NDUikFCjL._SL110_.jpg</URL>
                        <Height Units="pixels">73</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51NDUikFCjL._SL160_.jpg</URL>
                        <Height Units="pixels">107</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51NDUikFCjL.jpg</URL>
                        <Height Units="pixels">333</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51fgDM02ypL._SL30_.jpg</URL>
                        <Height Units="pixels">20</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51fgDM02ypL._SL75_.jpg</URL>
                        <Height Units="pixels">50</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51fgDM02ypL._SL75_.jpg</URL>
                        <Height Units="pixels">50</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51fgDM02ypL._SL110_.jpg</URL>
                        <Height Units="pixels">73</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51fgDM02ypL._SL160_.jpg</URL>
                        <Height Units="pixels">107</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51fgDM02ypL.jpg</URL>
                        <Height Units="pixels">333</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51glt7MXNWL._SL30_.jpg</URL>
                        <Height Units="pixels">20</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51glt7MXNWL._SL75_.jpg</URL>
                        <Height Units="pixels">50</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51glt7MXNWL._SL75_.jpg</URL>
                        <Height Units="pixels">50</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51glt7MXNWL._SL110_.jpg</URL>
                        <Height Units="pixels">73</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51glt7MXNWL._SL160_.jpg</URL>
                        <Height Units="pixels">107</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51glt7MXNWL.jpg</URL>
                        <Height Units="pixels">333</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51b6NgS7RKL._SL30_.jpg</URL>
                        <Height Units="pixels">20</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51b6NgS7RKL._SL75_.jpg</URL>
                        <Height Units="pixels">50</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51b6NgS7RKL._SL75_.jpg</URL>
                        <Height Units="pixels">50</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51b6NgS7RKL._SL110_.jpg</URL>
                        <Height Units="pixels">73</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51b6NgS7RKL._SL160_.jpg</URL>
                        <Height Units="pixels">107</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51b6NgS7RKL.jpg</URL>
                        <Height Units="pixels">333</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51Zklh3FDLL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51Zklh3FDLL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">74</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51Zklh3FDLL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">74</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51Zklh3FDLL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">109</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51Zklh3FDLL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">158</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51Zklh3FDLL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">495</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="variant">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51EjdXg3pEL._SL30_.jpg</URL>
                        <Height Units="pixels">20</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51EjdXg3pEL._SL75_.jpg</URL>
                        <Height Units="pixels">50</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51EjdXg3pEL._SL75_.jpg</URL>
                        <Height Units="pixels">50</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51EjdXg3pEL._SL110_.jpg</URL>
                        <Height Units="pixels">73</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51EjdXg3pEL._SL160_.jpg</URL>
                        <Height Units="pixels">107</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/51EjdXg3pEL.jpg</URL>
                        <Height Units="pixels">333</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
                <ImageSet Category="primary">
                    <SwatchImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/410VNyMfaOL._SL30_.jpg</URL>
                        <Height Units="pixels">30</Height>
                        <Width Units="pixels">30</Width>
                    </SwatchImage>
                    <SmallImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/410VNyMfaOL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </SmallImage>
                    <ThumbnailImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/410VNyMfaOL._SL75_.jpg</URL>
                        <Height Units="pixels">75</Height>
                        <Width Units="pixels">75</Width>
                    </ThumbnailImage>
                    <TinyImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/410VNyMfaOL._SL110_.jpg</URL>
                        <Height Units="pixels">110</Height>
                        <Width Units="pixels">110</Width>
                    </TinyImage>
                    <MediumImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/410VNyMfaOL._SL160_.jpg</URL>
                        <Height Units="pixels">160</Height>
                        <Width Units="pixels">160</Width>
                    </MediumImage>
                    <LargeImage>
                        <URL>https://images-na.ssl-images-amazon.com/images/I/410VNyMfaOL.jpg</URL>
                        <Height Units="pixels">500</Height>
                        <Width Units="pixels">500</Width>
                    </LargeImage>
                </ImageSet>
            </ImageSets>
            <ItemAttributes>
                <Binding>Kitchen</Binding>
                <Brand>Tosnail</Brand>
                <Color>Linen</Color>
                <Feature>Eco-friendly & durable storage bins: Made from natural durable Jute. EVA inside.</Feature>
                <Feature>Fits most shelves: Medium size 14.5" Long x 10" Wide x 8" High. Wire-framed for stability.</Feature>
                <Feature>Save space: Storage Basket is collapsible for easy storage.</Feature>
                <Feature>Make your stuff clean and tidy.</Feature>
                <Feature>Perfect for office, nursery, closet, bedrooms, bathrooms, pantry, desk, college dorm, craft area, and more.</Feature>
                <IsAdultProduct>0</IsAdultProduct>
                <ItemDimensions>
                    <Height Units="hundredths-inches">800</Height>
                    <Length Units="hundredths-inches">1450</Length>
                    <Weight Units="Hundredths Pounds">82</Weight>
                    <Width Units="hundredths-inches">1000</Width>
                </ItemDimensions>
                <Label>Tosnail</Label>
                <ListPrice>
                    <Amount>1299</Amount>
                    <CurrencyCode>USD</CurrencyCode>
                    <FormattedPrice>$12.99</FormattedPrice>
                </ListPrice>
                <Manufacturer>Tosnail</Manufacturer>
                <ManufacturerMaximumAge Units="months">99</ManufacturerMaximumAge>
                <ManufacturerMinimumAge Units="months">3</ManufacturerMinimumAge>
                <Model>T-JuteStorageBin</Model>
                <MPN>T-JuteStorageBin</MPN>
                <PackageDimensions>
                    <Height Units="hundredths-inches">180</Height>
                    <Length Units="hundredths-inches">1650</Length>
                    <Weight Units="Hundredths Pounds">80</Weight>
                    <Width Units="hundredths-inches">990</Width>
                </PackageDimensions>
                <PartNumber>T-JuteStorageBin</PartNumber>
                <ProductGroup>Baby Product</ProductGroup>
                <ProductTypeName>HOME</ProductTypeName>
                <Publisher>Tosnail</Publisher>
                <Studio>Tosnail</Studio>
                <Title>Tosnail Home Essentials Fabric Collapsible Convenient Storage Bin Nursery Baskets with Leather Handle For Bedroom, Closet, Toys, Laundry - Medium (14.5" Long x 10" Wide x 8" High)</Title>
            </ItemAttributes>
        </Item>
    </Items>
</ItemSearchResponse>""")
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-8-f74765ea03e6>", line 3147, in <module>
#     </ItemSearchResponse>""")
#
#   File "/usr/local/Cellar/python/3.6.4_3/Frameworks/Python.framework/Versions/3.6/lib/python3.6/xml/etree/ElementTree.py", line 1314, in XML
#     parser.feed(text)
#
#   File "<string>", line unknown
# ParseError: not well-formed (invalid token): line 1, column 0
